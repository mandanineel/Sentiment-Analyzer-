# %%
from PIL import Image
import pytesseract

image_file = "tweet03.jpg"
img = Image.open(image_file)

# %%
ocr_result = pytesseract.image_to_string(img)

# %%
print(ocr_result)
# Out:
# ‘Michae! Holding on Hardik
# Pandya: ;
#
# “I dont think he does a lot with
# the bal. Heis not consistent. He
# does not have the control that
# puts batsmen under pressure
# constantly”
#
# Pandya takes 5-28 at Trent Bridge.
# #ENGVIND

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=348x252>
